# %%
import pandas as pd
from PIL import Image
image = Image.open("./SAR-aircraft/SAR-aircraft/images/00009.bmp")
image.show()
print(image.format)  # 图像格式
print(image.size)    # 图像尺寸
print(image.mode)    # 图像模式
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=224x224>
# BMP
# (224, 224)
# RGB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 获取变换矩阵（GeoTransform）
# ----> 2 geo_transform = image.GetGeoTransform()
#       4 # 如果存在空间变换，打印 GeoTransform
#       5 if geo_transform:
#
# AttributeError: 'BmpImageFile' object has no attribute 'GetGeoTransform'
